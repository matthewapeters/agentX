# %% [markdown]
# # Debug Complex Task
#
#
# **We began using notebooks to validate the application with "test_classification" - the prompt will cause the agent to pursue a complex task.  Use the "debug_complex_task" notebook to re-create the prompt and environment conditions to test the complex task implementation**
#
# - TODO: Recreate the scenario from test_classifiction (and debug_tools and debug_complex) notebook.
# - TODO: Track the application process, capture any bugs, and correct the application code as necessary.
